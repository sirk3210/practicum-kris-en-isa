# %% [markdown]
# atmos = 180
# U1 = 180
# U2 = 330
# U3 = 550
# p40 = 1017.64 hpa
# p20 = 2*p40
# p10 = 2*p20
#
# b = p40
# p20 = a*U2 +b
# (p20-b)/U2 = a
#
# 1 zodat we de ruimte van de buis kunnen negeren
#
#
# met lange tube
# u1 = 180 met 40 dus
# u2 = 300 met 20 dus
# u3 = 440 met 10 dus

# %%
atmos = 180
U1 = 180
U2 = 330
U3 = 550
p40 = 101.764
p20 = 2*p40
p10 = 2*p20

b = p40
a = (p20-b)/U2
print(a, b)
